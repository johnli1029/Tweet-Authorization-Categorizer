# %%
import numpy as np

# %%
import pandas as pd

# %%
import os

# %%
print(os.listdir("./"))
# Out:
# ['.ipynb_checkpoints', 'Draft.ipynb', 'GroupAgreement.pdf', 'Project1.pdf', 'test_tweets_unlabeled.txt', 'test_tweets_unlabeled.txt.zip', 'train_tweets.txt', 'train_tweets.zip']

# %%
# %matplotlib inline

# %%
import itertools

# %%
import tensorflow as tf
# Out:
# c:\users\china\appdata\local\programs\python\python37\lib\site-packages\tensorflow\python\framework\dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# c:\users\china\appdata\local\programs\python\python37\lib\site-packages\tensorflow\python\framework\dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# c:\users\china\appdata\local\programs\python\python37\lib\site-packages\tensorflow\python\framework\dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# ...

# %%
# This code was tested with TensorFlow v1.8
print("You have TensorFlow version", tf.__version__)
# Out:
# You have TensorFlow version 1.14.0

# %%
TRAINSET_PATH = "./train_tweets.txt"

# %%
df = pd.read_csv(TRAINSET_PATH, sep='\t', encoding="utf-8", quoting=3, names=["user_id", "tweet"])

# %%
df.user_id = df.user_id.astype('str')

# %%
df
# Out:
#        user_id                                              tweet
# 0         8746     @handle Let's try and catch up live next week!
# 1         8746  Going to watch Grey's on the big screen - Thur...
# 2         8746  @handle My pleasure Patrick....hope you are well!
# 3         8746  @handle Hi there! Been traveling a lot and lot...
# 4         8746  RT @handle Looking to Drink Clean & Go Green? ...
# ...        ...                                                ...
# 328927    4357  Steelbox Demonstrates Open Video Framework wit...
# 328928    4357  Small Businesses Rely on Sage to Help Them Rid...
# 328929    4357  TimeSight Systems™ Announces Next-Generation P...
# 328930    4357  Diebold Makes Its Leading Monitoring Solutions...
# 328931    4357  GVI Security Solutions to Introduce AutoIP™ VM...
#
# [328932 rows x 2 columns]

# %%
df.describe()
# Out:
#        user_id        tweet
# count   328932       328932
# unique    9297       317837
# top       4185  @handle lol
# freq       284          110

# %%
MODIFIED_TRAINSET_PATH = './modified.csv'

# %%
df.to_csv(MODIFIED_TRAINSET_PATH, encoding='utf-8-sig', index=False)

# %%
df2 = pd.read_csv(MODIFIED_TRAINSET_PATH)

# %%
df2
# Out:
#         user_id                                              tweet
# 0          8746     @handle Let's try and catch up live next week!
# 1          8746  Going to watch Grey's on the big screen - Thur...
# 2          8746  @handle My pleasure Patrick....hope you are well!
# 3          8746  @handle Hi there! Been traveling a lot and lot...
# 4          8746  RT @handle Looking to Drink Clean & Go Green? ...
# ...         ...                                                ...
# 328927     4357  Steelbox Demonstrates Open Video Framework wit...
# 328928     4357  Small Businesses Rely on Sage to Help Them Rid...
# 328929     4357  TimeSight Systems™ Announces Next-Generation P...
# 328930     4357  Diebold Makes Its Leading Monitoring Solutions...
# 328931     4357  GVI Security Solutions to Introduce AutoIP™ VM...
#
# [328932 rows x 2 columns]
